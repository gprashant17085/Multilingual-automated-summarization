# %%
# !pip3 install torch torchvision

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# Out:
# Cloning into 'OpenNMT-py'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 16803 (delta 0), reused 5 (delta 0), pack-reused 16762
# Receiving objects: 100% (16803/16803), 223.30 MiB | 31.69 MiB/s, done.
# Resolving deltas: 100% (12093/12093), done.

# %%
# !pip install -r OpenNMT-py/requirements.opt.txt
# Out:
# ...
#   Cloning git://github.com/NVIDIA/apex.git (to revision 700d6825e205732c1d6be511306ca4e595297070) to /tmp/pip-req-build-vp2y3h1b
#   Running command git clone -q git://github.com/NVIDIA/apex.git /tmp/pip-req-build-vp2y3h1b
#   Running command git checkout -q 700d6825e205732c1d6be511306ca4e595297070
#   Running command git submodule update --init --recursive -q
# ...
#      |████████████████████████████████| 3.3MB 9.4MB/s
# ...
#      |████████████████████████████████| 20.2MB 1.2MB/s
# ...
#      |████████████████████████████████| 61kB 6.3MB/s
# ...
#      |████████████████████████████████| 1.1MB 40.9MB/s
# ...
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-cp36-none-any.whl size=191613 sha256=a99481bda7d960b23e168a36e5319766634f5c2a5babc1f7f86fca0621ed873a
#   Stored in directory: /root/.cache/pip/wheels/75/d3/0c/e5b04e15b6b87c42e980de3931d2686e14d36e045058983599
# ...

# %%
# !pip install -U git+https://github.com/pltrdy/pyrouge
# Out:
# ...
#   Cloning https://github.com/pltrdy/pyrouge to /tmp/pip-req-build-d06byw6z
#   Running command git clone -q https://github.com/pltrdy/pyrouge /tmp/pip-req-build-d06byw6z
# ...
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-cp36-none-any.whl size=191920 sha256=dba33b826ca45b497e4ad496c533bc8ebed35e8c62258c86d36e11ed4c4f9b7a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mmr3l827/wheels/d7/6a/52/2534a6d70b54de6e94933267ff415b0b85cdb83836af9f74c3
# Successfully built pyrouge
# ...
#   Found existing installation: pyrouge 0.1.3
#     Uninstalling pyrouge-0.1.3:
#       Successfully uninstalled pyrouge-0.1.3
# ...

# %%
# !git clone https://github.com/pltrdy/files2rouge.git
# Out:
# Cloning into 'files2rouge'...
# remote: Enumerating objects: 258, done.
# remote: Total 258 (delta 0), reused 0 (delta 0), pack-reused 258
# Receiving objects: 100% (258/258), 205.33 KiB | 8.55 MiB/s, done.
# Resolving deltas: 100% (124/124), done.

# %%
cd files2rouge
# Out:
# /content/files2rouge

# %%
ls
# Out:
# Dockerfile    files2rouge/  MANIFEST.in  setup.py
# experiments/  LICENSE       README.md    setup_rouge.py*

# %%
# !python3 setup_rouge.py
# Out:
# files2rouge uses scripts and tools that will not be stored with the python package
# where do you want to save it? [default: /root/.files2rouge/]
# Copying './files2rouge/RELEASE-1.5.5/' to '/root/.files2rouge/'

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating files2rouge.egg-info
# writing files2rouge.egg-info/PKG-INFO
# writing dependency_links to files2rouge.egg-info/dependency_links.txt
# writing entry points to files2rouge.egg-info/entry_points.txt
# writing top-level names to files2rouge.egg-info/top_level.txt
# writing manifest file 'files2rouge.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'files2rouge.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/files2rouge
# copying files2rouge/__init__.py -> build/lib/files2rouge
# copying files2rouge/utils.py -> build/lib/files2rouge
# copying files2rouge/settings.py -> build/lib/files2rouge
# copying files2rouge/files2rouge.py -> build/lib/files2rouge
# copying files2rouge/settings.json -> build/lib/files2rouge
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/DSGA_1011_NLP_Project'
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# Out:
# fatal: destination path 'OpenNMT-py' already exists and is not an empty directory.

# %%
# !pip install -r OpenNMT-py/requirements.opt.txt
# Out:
# ...
#   Cloning git://github.com/NVIDIA/apex.git (to revision 700d6825e205732c1d6be511306ca4e595297070) to /tmp/pip-req-build-t7vlahn2
#   Running command git clone -q git://github.com/NVIDIA/apex.git /tmp/pip-req-build-t7vlahn2
#   Running command git checkout -q 700d6825e205732c1d6be511306ca4e595297070
#   Running command git submodule update --init --recursive -q
# ...
#   Created wheel for apex: filename=apex-0.1-cp36-none-any.whl size=192741 sha256=0b108dc3990d73d2865425624025261dc1f18cbfc64b2c48898402e090120206
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lm5wj0yo/wheels/79/9c/88/e32489e77c08ebfae4d4c737d647510fcfc1a0b3aed2bd9991
# Successfully built apex

# %%
ls
# Out:
#  ACL_2020_Proceedings_Template.pdf   Gig_colab.ipynb
#  CNN_Daily_Mail.ipynb                OpenNMT-py/
#  Data/                               Ted_Talks_EDA.ipynb
# 'DSGA1011 NLP Project.gdoc'          Ted_Talks_EDA_v2.ipynb
#  EUROPARL_INSPECTION.ipynb

# %%
cd Data
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project/Data

# %%
ls
# Out:
#  cnndm/         Euro-parl/       ted2013.en-es.xliff      train.v2.log
#  cnndm.tar.gz   gigaword/        ted2013.en-es.xliff.gz   untitled
#  cnndm.yaml     rnncnn.yaml     'TED_TALK_ES-EN '/
#  es-en.tgz      summary.tar.gz   TED_TALK_ES-EN.tgz

# %%
cd ..
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project

# %%
# !vim train.article.txt
# Out:
# /bin/bash: vim: command not found

# %%
# !sed ‘s/<unk>/UNK/g’ train.article.txt > train.article.cleaned.txt
# Out:
# /bin/bash: unk: No such file or directory

# %%
ls
# Out:
#  train.article.txt     'train.title.txt.gz (Unzipped Files)'/
#  train.article.txt.gz   valid.article.filter.txt
#  train.title.txt.gz     valid.title.filter.txt

# %%
ls
# Out:
# benchmark/       Dockerfile    lm.lua          rocks/    train.lua
# CHANGELOG.md     docs/         mkdocs.yml      STYLE.md  translate.lua
# codecov.yml      files2rouge/  onmt/           tag.lua
# CONTRIBUTING.md  hooks/        preprocess.lua  test/
# data/            LICENSE.md    README.md       tools/

# %%
ls
# Out:
#  ACL_2020_Proceedings_Template.pdf   Gig_colab.ipynb
#  CNN_Daily_Mail.ipynb                OpenNMT-py/
#  Data/                               Ted_Talks_EDA.ipynb
# 'DSGA1011 NLP Project.gdoc'          Ted_Talks_EDA_v2.ipynb
#  EUROPARL_INSPECTION.ipynb

# %%
# !pip install configargparse
#!pip install torch==1.7.0
# !pip install git+https://github.com/pytorch/text
# Out:
# ...
#      |████████████████████████████████| 51kB 3.6MB/s
# ...
#   Created wheel for configargparse: filename=ConfigArgParse-1.2.3-cp36-none-any.whl size=19329 sha256=c06635970f3505ec386e8069a56ad37293a839fda41316dd04fa2487085224e1
#   Stored in directory: /root/.cache/pip/wheels/bd/d6/53/034032da9498bda2385cd50a51a289e88090b5da2d592b1fdf
# Successfully built configargparse
# ...
#   Cloning https://github.com/pytorch/text to /tmp/pip-req-build-us9dswdj
#   Running command git clone -q https://github.com/pytorch/text /tmp/pip-req-build-us9dswdj
#   Running command git submodule update --init --recursive -q
# ...
#   Created wheel for torchtext: filename=torchtext-0.9.0a0+ec413ff-cp36-cp36m-linux_x86_64.whl size=7061470 sha256=3ce587831663b38e27d371c0d7d41a4f7a4f9d5f62c773f92c26150196cfb2b1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mu5utbte/wheels/73/14/71/ed033fd999ae4933e17df3e91be2014e61c2f312a88a164ff5
# Successfully built torchtext
# ...
#   Found existing installation: torchtext 0.3.1
# ...

# %%
ls
# Out:
# available_models/  data/                   LICENSE.md            setup.py
# build/             dist/                   onmt/                 tools/
# build_vocab.py     docs/                   OpenNMT_py.egg-info/  train.py
# CHANGELOG.md       examples/               README.md             translate.py
# config/            floyd_requirements.txt  requirements.opt.txt
# CONTRIBUTING.md    floyd.yml               server.py

# %%
cd tools
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project/OpenNMT-py/tools

# %%
# !python -u train.py \
 -save_model Data/gigaword/models_v2/ \
 -data data/gigaword/PREPROCESSED \
 -copy_attn \
 -global_attention mlp \
 -word_vec_size 128 \
 -rnn_size 512 \
 -layers 2 \
 -encoder_type brnn \
 -train_steps 2000000 \
 -report_every 100 \
 -valid_steps 10000 \
 -valid_batch_size 32 \
 -max_generator_batches 128 \
 -save_checkpoint_steps 10000 \
 -max_grad_norm 2 \
 -dropout 0.1 \
 -batch_size 16 \
 -optim adagrad \
 -learning_rate 0.15 \
 -start_decay_steps 100000 \
 -decay_steps 50000 \
 -adagrad_accumulator_init 0.1 \
 -reuse_copy_attn \
 -copy_loss_by_seqlength \
 -bridge \
 -seed 919 \
 -gpu_ranks 0 \
 -log_file train.v2.log
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory

# %%
ls
# Out:
#  ACL_2020_Proceedings_Template.pdf   Gig_colab.ipynb
#  CNN_Daily_Mail.ipynb                OpenNMT-py/
#  Data/                               Ted_Talks_EDA.ipynb
# 'DSGA1011 NLP Project.gdoc'          Ted_Talks_EDA_v2.ipynb
#  EUROPARL_INSPECTION.ipynb

# %%
cd OpenNMT-py
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project/OpenNMT-py

# %%
ls
# Out:
# available_models/  data/                   LICENSE.md            setup.py
# build_vocab.py     docs/                   onmt/                 tools/
# CHANGELOG.md       examples/               README.md             train.py
# config/            floyd_requirements.txt  requirements.opt.txt  translate.py
# CONTRIBUTING.md    floyd.yml               server.py

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py/tree/legacy
# Out:
# Cloning into 'legacy'...
# fatal: repository 'https://github.com/OpenNMT/OpenNMT-py/tree/legacy/' not found

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating OpenNMT_py.egg-info
# writing OpenNMT_py.egg-info/PKG-INFO
# writing dependency_links to OpenNMT_py.egg-info/dependency_links.txt
# writing entry points to OpenNMT_py.egg-info/entry_points.txt
# writing requirements to OpenNMT_py.egg-info/requires.txt
# writing top-level names to OpenNMT_py.egg-info/top_level.txt
# writing manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# writing manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/onmt
# copying onmt/__init__.py -> build/lib/onmt
# copying onmt/constants.py -> build/lib/onmt
# copying onmt/model_builder.py -> build/lib/onmt
# copying onmt/opts.py -> build/lib/onmt
# copying onmt/train_single.py -> build/lib/onmt
# copying onmt/trainer.py -> build/lib/onmt
# creating build/lib/onmt/bin
# ...

# %%
ls
# Out:
# available_models/  data/                   LICENSE.md            setup.py
# build/             dist/                   onmt/                 tools/
# build_vocab.py     docs/                   OpenNMT_py.egg-info/  train.py
# CHANGELOG.md       examples/               README.md             translate.py
# config/            floyd_requirements.txt  requirements.opt.txt
# CONTRIBUTING.md    floyd.yml               server.py

# %%
cd ..
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project

# %%
cd Data
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project/Data

# %%
ls
# Out:
#  cnndm/         Euro-parl/       ted2013.en-es.xliff      train.v2.log
#  cnndm.tar.gz   gigaword/        ted2013.en-es.xliff.gz   untitled
#  cnndm.yaml     rnncnn.yaml     'TED_TALK_ES-EN '/
#  es-en.tgz      summary.tar.gz   TED_TALK_ES-EN.tgz

# %%
cd gigaword/
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project/Data/gigaword

# %%
ls
# Out:
# DUC2003/  DUC2004/  files2rouge/  Giga/  opennmt/  sumdata/  train/

# %%
cd opennmt/
# Out:
# /content/drive/.shortcut-targets-by-id/1zJEzU7AONU-4f_78lpneSWk_NcBn0nda/DSGA_1011_NLP_Project/Data/gigaword/opennmt

# %%
# !th preprocess.lua -train_src ../data/train/train.article.txt -train_tgt ../data/train/train.title.txt -valid_src ../data/train/valid.article.filter.txt -valid_tgt ../data/train/valid.title.filter.txt -save_data ../data/train/textsum
# Out:
# /bin/bash: th: command not found

# %%
# !bash
# Out:
# bash: cannot set terminal process group (55): Inappropriate ioctl for device
# bash: no job control in this shell
# ave_data ../data/train/textsum
# bash: th: command not found
# 11_NLP_Project/Data/gigaword/opennmt#

# %%
th preprocess.lua -train_src ../data/train/train.article.txt -train_tgt ../data/train/train.title.txt -valid_src ../data/train/valid.article.filter.txt -valid_tgt ../data/train/valid.title.filter.txt -save_data ../data/train/textsum
