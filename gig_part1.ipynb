# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/nlp_project'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-74-bc56c1aa33ca>", line 1, in <module>
#     get_ipython().magic("cd '/content/drive/MyDrive/nlp_project'")
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
cd opennmt/
# Out:
# /content/drive/MyDrive/nlp_project/opennmt

# %%
# !pip install configargparse

# %%
# !pip install git+https://github.com/pytorch/text
# Out:
# ...
#   Cloning https://github.com/pytorch/text to /tmp/pip-req-build-6_8df9lw
#   Running command git clone -q https://github.com/pytorch/text /tmp/pip-req-build-6_8df9lw
#   Running command git submodule update --init --recursive -q
# ...
#   Created wheel for torchtext: filename=torchtext-0.9.0a0+ec413ff-cp36-cp36m-linux_x86_64.whl size=7048898 sha256=2a15da9eb9bd932f1062d49c9f426c0978742ac04365ceebf3616054fbeac16a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rp5s0i79/wheels/73/14/71/ed033fd999ae4933e17df3e91be2014e61c2f312a88a164ff5
# Successfully built torchtext
# ...
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# ...

# %%
# !python preprocess.py -train_src ./data/train/train.article.txt -train_tgt ./data/train/train.title.txt -valid_src ./data/train/valid.article.filter.txt -valid_tgt ./data/train/valid.title.filter.txt -save_data ./data/train/textsum
# Out:
# [2020-12-06 07:10:37,876 INFO] Extracting features...
# [2020-12-06 07:10:38,778 INFO]  * number of source features: 0.
# [2020-12-06 07:10:38,778 INFO]  * number of target features: 0.
# [2020-12-06 07:10:38,778 INFO] Building `Fields` object...
# /usr/local/lib/python3.6/dist-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /usr/local/lib/python3.6/dist-packages/torchtext/data/field.py:36: UserWarning: TextMultiField class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
# ...

# %%
ls
# Out:
# available_models/                         setup.py
# CHANGELOG.md                              textsum2_step_10000.pt
# config/                                   textsum2_step_15000.pt
# CONTRIBUTING.md                           textsum2_step_20000.pt
# data/                                     textsum2_step_25000.pt
# docs/                                     textsum2_step_30000.pt
# floyd_requirements.txt                    textsum2_step_35000.pt
# floyd.yml                                 textsum2_step_40000.pt
# github_deploy_key_opennmt_opennmt_py.enc  textsum2_step_45000.pt
# LICENSE.md                                textsum2_step_50000.pt
# onmt/                                     textsum2_step_5000.pt
# preprocess.py                             tools/
# README.md                                 train.py
# requirements.opt.txt                      train.v2.log
# server.py                                 translate.py

# %%
ls
# Out:
# available_models/                         setup.py
# CHANGELOG.md                              textsum2_step_10000.pt
# config/                                   textsum2_step_15000.pt
# CONTRIBUTING.md                           textsum2_step_20000.pt
# data/                                     textsum2_step_25000.pt
# docs/                                     textsum2_step_30000.pt
# floyd_requirements.txt                    textsum2_step_35000.pt
# floyd.yml                                 textsum2_step_40000.pt
# github_deploy_key_opennmt_opennmt_py.enc  textsum2_step_45000.pt
# LICENSE.md                                textsum2_step_50000.pt
# onmt/                                     textsum2_step_5000.pt
# preprocess.py                             tools/
# README.md                                 train.py
# requirements.opt.txt                      train.v2.log
# server.py                                 translate.py

# %%
# !python -u train.py -data ./data/train/textsum -save_model textsum2 -gpu_ranks 0
# Out:
# [2020-12-06 07:10:44,223 INFO]  * src vocab size = 50002
# [2020-12-06 07:10:44,223 INFO]  * tgt vocab size = 50004
# [2020-12-06 07:10:44,223 INFO] Building model...
# [2020-12-06 07:10:56,024 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50002, 500, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(500, 500, num_layers=2, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 500, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.3, inplace=False)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3, inplace=False)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
#     )
#     (attn): GlobalAttention(
# ...

# %%
# !python ../opennmt/preprocess.py \
#  -train_src data/train/train.article.txt \
#  -train_tgt data/train/train.title.txt \
#  -valid_src data/train/valid.article.filter.txt \
#  -valid_tgt data/train/valid.title.filter.txt \
#  -save_data data/PREPROCESSED \
#  -src_seq_length 10000 \
#  -dynamic_dict \
#  -share_vocab

# %%
# !nvidia-smi

# %%
# !python -u ../opennmt/train.py \
#  -save_model data/models_v3/ \
#  -data data/train/textsum \
#  -global_attention mlp \
#  -word_vec_size 128 \
#  -rnn_size 512 \
#  -layers 2 \
#  -encoder_type brnn \
#  -train_steps 2000000 \
#  -report_every 100 \
#  -valid_steps 10000 \
#  -valid_batch_size 32 \
#  -max_generator_batches 128 \
#  -save_checkpoint_steps 10000 \
#  -max_grad_norm 2 \
#  -dropout 0.1 \
#  -batch_size 16 \
#  -optim adagrad \
#  -learning_rate 0.15 \
#  -start_decay_steps 100000 \
#  -decay_steps 50000 \
#  -adagrad_accumulator_init 0.1 \
#  -reuse_copy_attn \
#  -copy_loss_by_seqlength \
#  -bridge \
#  -seed 919 \
#  -gpu_ranks 0 \
#  -log_file train.v2.log

# %%
# !python translate.py -model textsum2_step_100000.pt -src ./data/Giga/input.txt -gpu 0
# Out:
# [2020-12-06 12:34:22,454 INFO] Translating shard 0.
# /usr/local/lib/python3.6/dist-packages/torchtext/data/example.py:52: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# /usr/local/lib/python3.6/dist-packages/torchtext/data/iterator.py:48: UserWarning: OrderedIterator class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# ...

# %%
cd files2rouge/
# Out:
# /content/drive/My Drive/nlp_project/opennmt/data/files2rouge/files2rouge

# %%
# !python files2rouge.py .../opennmt/pred.txt ../data/Giga/task1_ref0.txt
# Out:
# Traceback (most recent call last):
#   File "files2rouge.py", line 16, in <module>
#     from files2rouge import settings
#   File "/content/drive/My Drive/nlp_project/opennmt/data/files2rouge/files2rouge/files2rouge.py", line 16, in <module>
#     from files2rouge import settings
# ImportError: cannot import name 'settings'

# %%
ls
# Out:
# files2rouge.py  __pycache__/    settings.py
# __init__.py     RELEASE-1.5.5/  utils.py

# %%
cd ../..
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-60-961f95c527f4>", line 1, in <module>
#     get_ipython().magic('cd ../..')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/osm.py", line 288, in cd
# ...

# %%
ls
# Out:
# ls: cannot open directory '.': No such file or directory

# %%
cd ..
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-392013b89fb5>", line 1, in <module>
#     get_ipython().magic('cd ..')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/osm.py", line 356, in cd
# ...

# %%
ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ls: cannot open directory '.': No such file or directory

# %%
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-67-5589a4cc9218>", line 1, in <module>
#     get_ipython().magic("cd -'dir'")
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/osm.py", line 288, in cd
# ...

# %%
cd '/content/drive/MyDrive/nlp_project'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-68-bc56c1aa33ca>", line 1, in <module>
#     get_ipython().magic("cd '/content/drive/MyDrive/nlp_project'")
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...
